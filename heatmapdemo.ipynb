# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

parameter = ["Passing", "Shooting", "Ball Control", "Crossing", "Tackling", "Defense"]
player = ["Ronaldo", "Messi", "Casimero", "Rashford", "Haaland", "Van Djik"]

stats = np.array([[0.8, 0.9, 0.7, 0.5, 0.4, 0.3],
                    [1.0, 1.0, 0.5, 0.6, 0.2, 0.1],
                    [0.7, 1.0, 0.7, 0.4, 0.6, 0.6],
                    [0.8, 0.7, 0.6, 0.7, 0.4, 0.3],
                    [0.6, 0.4, 0.7, 0.3, 0.3, 1.0],                                        
                    [0.4, 0.3, 0.7, 0.5, 0.2, 1.0]])

fig, ax = plt.subplots(figsize=(7, 7))
im = ax.imshow(stats, cmap='Greens')

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(player)), labels=player)
ax.set_yticks(np.arange(len(parameter)), labels=parameter)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(parameter)):
    for j in range(len(player)):
        text = ax.text(j, i, stats[i, j],
                       ha="center", va="center", color="black")

ax.set_title("Compare World Football Stars Based On Key Parameters")
fig.tight_layout()
plt.show()

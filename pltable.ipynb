# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
teamColours = ['#034694','#001C58','#5CBFEB','#D00027',
              '#EF0107','#DA020E','#274488','#ED1A3B',
               '#000000','#091453','#60223B','#0053A0',
               '#E03A3E','#1B458F','#000000','#53162f',
               '#FBEE23','#EF6610','#C92520','#BA1F1A']


table = pd.read_csv("C:/Users/pc/Downloads/PL_Points_22_23.csv")
plt.bar(x=np.arange(1,21),height=table['Points'],color = teamColours)
plt.title("PL League Table 22/23")
plt.xticks(np.arange(1,21),table['Team'],rotation=90)
plt.xlabel("Team")
plt.ylabel("Points")
plt.show()
